# %%
import requests
import re 
import string 
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
# Make a request to the website
r = requests.get('https://bola.kompas.com/')
# Create an object to parse the HTML format
soup = BeautifulSoup(r.content, 'html.parser')
# Retrieve all popular news links (Fig. 1)
link = []
for i in soup.find('div', {'class':'most__wrap'}).find_all('a'):
    i['href'] = i['href'] + '?page=all'
    link.append(i['href'])
# For each link, we retrieve paragraphs from it, combine each paragraph as one string, and save it to documents (Fig. 2)
documents = []
for i in link:
    # Make a request to the link
    r = requests.get(i)
  
    # Initialize BeautifulSoup object to parse the content 
    soup = BeautifulSoup(r.content, 'html.parser')
  
    # Retrieve all paragraphs and combine it as one
    sen = []
    for i in soup.find('div', {'class':'read__content'}).find_all('p'):
        sen.append(i.text)
  
    # Add the combined paragraphs to documents
    documents.append(' '.join(sen))

documents_clean = []
for d in documents:
    # Remove Unicode
    document_test = re.sub(r'[^\x00-\x7F]+', ' ', d)
    # Remove Mentions
    document_test = re.sub(r'@\w+', '', document_test)
    # Lowercase the document
    document_test = document_test.lower()
    # Remove punctuations
    document_test = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', document_test)
    # Lowercase the numbers
    document_test = re.sub(r'[0-9]', '', document_test)
    # Remove the doubled space
    document_test = re.sub(r'\s{2,}', ' ', document_test)
    documents_clean.append(document_test)

# Instantiate a TfidfVectorizer object
vectorizer = TfidfVectorizer()
# It fits the data and transform it as a vector
X = vectorizer.fit_transform(documents_clean)
# Convert the X as transposed matrix
X = X.T.toarray()
# Create a DataFrame and set the vocabulary as the index
df = pd.DataFrame(X, index=vectorizer.get_feature_names())

def get_similar_articles(q, df):
  print("query:", q)
  print("Berikut artikel dengan nilai cosine similarity tertinggi: ")
  # Convert the query become a vector
  q = [q]
  q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0],)
  sim = {}
  # Calculate the similarity
  for i in range(10):
    sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)
  
  # Sort the values 
  sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)
  # Print the articles and their similarity values
  for k, v in sim_sorted:
    if v != 0.0:
      print("Nilai Similaritas:", v)
      print(documents_clean[k])
      print()
# Add The Query
q1 = 'barcelona'

get_similar_articles(q1, df)
# Out:
# query: barcelona
# Berikut artikel dengan nilai cosine similarity tertinggi:
# Nilai Similaritas: 0.09224238937432623
# kompas com duel mesir vs spanyol akan membuka rangkaian fase grup sepak bola putra olimpiade tokyo laga mesir vs spanyol yang termasuk pertandingan grup c akan berlangsung di sapporo dome hari ini kamis pukul wib link live streaming pertandingan kedua kesebelasan akan tersedia di akhir artikel ini spanyol turut membawa enam pemain yang sebelumnya mentas di euro yakni unai simon eric garcia pedri mikel oyarzabal pau torres dan dani olmo baca juga skuad spanyol untuk olimpiade tokyo selain enam pemain tersebut pelatih luis de la fuente juga turut memanggil nama nama top seperti dani ceballos mikel merino marco asensio dan oscar mingueza spanyol mengusung misi mengakhiri puasa medali emas sepak bola olimpiade kali terakhir spanyol merebut medali emas adalah pada olimpiade barcelona yang digelar di tanah sendiri dapatkan informasi inspirasi dan insight di email kamu daftarkan email pada olimpiade sydney spanyol berhasil menembus partai final namun mereka kalah dari kamerun pada pertandingan pamungkas sehingga harus puas dengan medali perak baca juga jadwal siaran langsung sepak bola olimpiade tokyo big match brasil vs jerman dani ceballos pun berharap dia dan rekan rekannya bisa mempersembahkan medali emas dan merasakan euforia kemenangan di olimpiade saya bahkan belum lahir ketika spanyol meraih medali emas di olimpiade barcelona ujar dani ceballos dilansir dari situs resmi federasi sepak bola spanyol akan sangat bagus untuk bisa mengalami hal seperti itu tutur ceballos melanjutkan pertandingan mesir vs spanyol bisa disaksikan melalui link live streaming di aplikasi vidio com klik tautan berikut untuk menyaksikan laga antara mesir dan spanyol klik di sini
#
# Nilai Similaritas: 0.027555375001105505
# kompas com rangkaian fase grup sepak bola putra olimpiade tokyo dibuka dengan sejumlah hasil mengejutkan tim tim besar seperti perancis dan argentina harus menelan kekalahan pada laga pertama fase grup sepak bola putra olimpiade tokyo yang telah digelar pada kamis sore hingga malam wib tersebut perancis yang membawa status juara dunia takluk saat bersua meksiko tak tanggung tanggung mereka kalah dengan skor telak adapun keempat gol yang membenamkan perancis dicetak oleh empat pemain berbeda yakni alexis vega sebastian cordova uriel antuna dan eduardo aguirre baca juga hasil meksiko vs perancis ayam jantan babak belur di laga perdana olimpiade sementara itu satu gol hiburan untuk perancis tercipta melalui eksekusi penalti andre pierre gignac pada menit ke hasil ini tentu menjadi awal yang buruk bagi timnas perancis mereka kini tertahan di dasar klasemen grup a sepak bola putra olimpiade tokyo dapatkan informasi inspirasi dan insight di email kamu daftarkan email setelah perancis tim besar lain yaitu argentina juga mengawali perjuangan dengan hasil buruk timnas berjulukan la albiceleste itu harus menelan kekelahan saat bersua pesaingnya di grup c australia baca juga hasil argentina vs australia bermain personel albiceleste terkapar argentina takluk akibat sepasang gol yang dibukukan lachlan wales dan marco tilio kekalahan argentina pun diwarnai oleh kartu merah francisco ortega beberapa menit menjelang turun minum babak pertama selanjutnya spanyol selaku pesaing argentina di grup c juga menelan hasil minor mereka ditahan imbang mesir dengan skor kacamata alias hasil tersebut memuluskan langkah australia yang berhasil memetik kemenangan atas argentina baca juga hasil mesir vs spanyol ditinggal ceballos yang cedera engkel laroja buntu australia untuk sementara memimpin klasemen grup c dengan koleksi tiga poin saat tiga pesaing lain gagal memetik poin penuh pada matchday pertama ini setelah itu jerman juga menjadi salah satu tim besar yang menelan kekalahan namun jerman takluk dari tim besar lainnya yakni brasil skuad berjulukan der panzer itu menyerah dalam duel yang berakhir dengan skor penyerang everton richarlison menjadi momok utama timnas jerman setelah dirinya mampu mencetak hat trick atau tiga gol baca juga brasil vs jerman diwarnai hattrick richarlison tim samba menangi drama gol adapun satu gol tambahan untk brasil dibukukan oleh paulinho sedangkan sepasang gol yang dicetak jerman tercipta berkat aksi nadiem amiri dan ragnar ache hasil ini membuat jerman terpuruk di dasar klasemen grup d mereka kalah selisih gol dari arab saudi yang menelan kekalahan dari pantai gading selain tim tim besar yang berjatuhan rangkaian matchday pertama fase grup sepak bola putra olimpiade tokyo juga diwarnai dengan aksi memukau messi jepang takefusa kubo kubo kerap disebut sebut sebagai messi jepang karena memiliki kelincahan dan kekuatan kaki kiri layaknya sang megabintang lionel messi baca juga alasan barcelona relakan lionel messi jepang dicaplok real madrid pada matchday pertama fase grup sepak bola putra olimpiade tokyo ini dia berhasil menjadi pahlawan kemenangan jepang kubo mencetak satu gol pada menit ke dan membantu jepang menang atas afrika selatan seperti julukannya kubo beraksi seperti messi ketika mencetak gol dia membobol gawang afrika selatan lewat sepakan kaki kiri yang akurat dan keras berkat kemenangan ini jepang berhak menempati peringkat kedua klasemen grup a mereka hanya kalah selisih gol dari meksiko yang tampil mengejutkan dengan mengalahkan perancis baca juga pembagian grup dan jadwal lengkap sepak bola olimpiade tokyo kamis sepak bola putra grup amaksiko perancisjepang afrika selatan grup bselandia baru korea selatanhonduras rumania grup cmesir spanyolargentina australia grup dpantai gading arab saudibrasil jerman
#
# Nilai Similaritas: 0.01947171792981993
#  kompas com ada tujuh calon bintang sepak bola yang siap meledak di olimpiade tokyo siapa saja mereka gelaran olimpiade musim panas akan mulai bergulir pada juli hingga agustus namun cabor sepak bola putra dijadwalkan berlangsung lebih cepat yakni pada juli satu hari sebelum upacara pembukaan olimpiade tokyo dan akan berakhir pada agustus sebanyak tim peserta siap memperebutkan tiga medali di olimpiade yakni emas perak dan perunggu selain persaingan memperebutkan medali olimpiade ada juga calon bintang sepak bola di pesta olahraga multicabang terbesar di dunia itu baca juga daftar peserta dan pembagian grup cabor sepak bola putra olimpiade tokyo dapatkan informasi inspirasi dan insight di email kamu daftarkan email berikut adalah daftar calon bintang sepak bola yang berpotensi tampil meledak di olimpiade tokyo pemain muda berusia tahun ini tentu saja masuk dalam daftar calon bintang pada gelaran olimpiade tokyo berbekal penampilan apik bersama timnas spanyol besutan luis enrique pada euro dan diganjar penghargaan sebagai pemain muda terbaik bukan tak mungkin pedri akan menjadi bintang pada gelaran olimpiade apalagi pedri berhasrat ingin membawa negaranya menjadi juara cabor sepak bola putra olimpiade tokyo saya berharap bisa meraih medali emas untuk spanyol di olimpiade kata pedri seperti dilansir mundo deportivo dari laman resmi rfef semuanya terjadi begitu cepat dari satu hari ke hari berikut saya kemudian sadar bahwa saya bermain untuk barcelona timnas spanyol dan sekarang di olimpiade tutur pedri baca juga sejarah singkat cabor sepak bola di olimpiade korea selatan memang tidak diperkuat bintang tottenham hotspur son heung min pada olimpiade namun wonderkid milik klub la liga valencia lee kang in siap memberikan penampilan terbaik di olimpiade bersama korea selatan lee kan in adalah pemain berposisi gelandang serang milik valencia pada musim lalu ia telah mencatatkan penampilan dengan membukukan satu gol dan empat assist di semua kompetisi gelandang serang berusia tahun itu bukan pemain sembarangan meningat dirinya juga tergabung dalam skuad korea selatan yang menjadi runner up piala dunia u meski usianya tak lagi muda dani alves masih menjadi salah satu full back kanan terhebat di dunia pemain berusia tahun itu akan mengawal sisi kanan belakang brasil pada olimpiade umpan umpan silang berbahaya alves tentu saja akan menyulitkan lawan dan justru memanjakan striker timnas brasil yang dihuni oleh richarlison dan matheus cunha tentu saja emas olimpiade akan menjadi cara yang bagus untuk mengakhiri karier alves di pentas internasionalnya baca juga skuad argentina untuk olimpiade tokyo pemain muda berbakat asal jepang ini merupakan salah satu talenta terbaik di wilayah asia yang saat ini dimiliki oleh real madrid kubo merupakan pemain yang kenyang pengalaman di berbagai kelompok umur timnas jepang mulai dari u u u u hingga senior adapun kubo menjadi viral bulan lalu ketika dia mencetak gol yang membuat empat pemain bertahan merasakan nutmeg tentunya penampilan apiknya akan terus berlanjut di olimpiade mengingat status jepang sebagai tuan rumah palang pintu berusia tahun ini juga masuk dalam daftar calon bintang di olimpiade tokyo bukan tanpa sebab ia akan bersinar di olimpiade mengingat performa impresifnya semenjak gabung klub serie a bologna pada semenjak bergabung tomiyasu langsung mendapat satu tempat utama di bologna ia sejauh ini telah mencatatkan penampilan bersama bologna dengan memmbukukan tiga gol dan tiga assist selama dua musim bukan hanya itu saja di level internasional tomiyasu juga merupakan andalan timnas jepang berbagai kategori umur di timnas senior jepang tomiyasu sejauh ini telah mencatatkan caps penampilan apik tomiyasu selama dua musim terakhir ini tentu saja diharapkan menular bersama jepang di olimpiade tokyo baca juga daftar negara peraih emas cabor sepak bola putra olimpiade siapa terbanyak amad diallo merupakan satu dari pemain yang dipanggil pelatih soualiho haidara untuk memperkuat timnas pantai gad ...

# %%
import requests
import re 
import string 
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
# Make a request to the website
r = requests.get('https://en.wikipedia.org/wiki/Reliance_Industries')
# Create an object to parse the HTML format
soup = BeautifulSoup(r.content, 'html.parser')
# Retrieve all popular news links (Fig. 1)
link = []
for i in soup.find('div', {'class':'most__wrap'}).find_all('a'):
    i['href'] = i['href'] + '?page=all'
    link.append(i['href'])
# For each link, we retrieve paragraphs from it, combine each paragraph as one string, and save it to documents (Fig. 2)
documents = []
for i in link:
    # Make a request to the link
    r = requests.get(i)
  
    # Initialize BeautifulSoup object to parse the content 
    soup = BeautifulSoup(r.content, 'html.parser')
  
    # Retrieve all paragraphs and combine it as one
    sen = []
    for i in soup.find('div', {'class':'read__content'}).find_all('p'):
        sen.append(i.text)
  
    # Add the combined paragraphs to documents
    documents.append(' '.join(sen))

documents_clean = []
for d in documents:
    # Remove Unicode
    document_test = re.sub(r'[^\x00-\x7F]+', ' ', d)
    # Remove Mentions
    document_test = re.sub(r'@\w+', '', document_test)
    # Lowercase the document
    document_test = document_test.lower()
    # Remove punctuations
    document_test = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', document_test)
    # Lowercase the numbers
    document_test = re.sub(r'[0-9]', '', document_test)
    # Remove the doubled space
    document_test = re.sub(r'\s{2,}', ' ', document_test)
    documents_clean.append(document_test)

# Instantiate a TfidfVectorizer object
vectorizer = TfidfVectorizer()
# It fits the data and transform it as a vector
X = vectorizer.fit_transform(documents_clean)
# Convert the X as transposed matrix
X = X.T.toarray()
# Create a DataFrame and set the vocabulary as the index
df = pd.DataFrame(X, index=vectorizer.get_feature_names())

def get_similar_articles(q, df):
  print("query:", q)
  print("Berikut artikel dengan nilai cosine similarity tertinggi: ")
  # Convert the query become a vector
  q = [q]
  q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0],)
  sim = {}
  # Calculate the similarity
  for i in range(10):
    sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)
  
  # Sort the values 
  sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)
  # Print the articles and their similarity values
  for k, v in sim_sorted:
    if v != 0.0:
      print("Nilai Similaritas:", v)
      print(documents_clean[k])
      print()
# Add The Query
q1 = 'Ambani'

get_similar_articles(q1, df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-14821377fdc0> in <module>()
#      12 # Retrieve all popular news links (Fig. 1)
#      13 link = []
# ---> 14 for i in soup.find('div', {'class':'most__wrap'}).find_all('a'):
#      15     i['href'] = i['href'] + '?page=all'
#      16     link.append(i['href'])
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
